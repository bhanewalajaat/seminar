# %% [markdown]
# # Content
#
# - **Introduction**
# - **Pandas**
# - **Matplotlib**
# - **Seaborn**
# - **Dash**
# - **Summary**
# - **References**

# %% [markdown]
# # Introduction
#
# - **Data wrangling** is the process of cleaning and unifying messy and complex data sets for easy access and analysis.
# - Amount of data and data sources rapidly growing and expanding.
# - It is challenging the large amount of available data to be organized for analysis.
#
# - 80% time and effort is spent in data wrangling due to various sizes, shapes and different nature of data.
# - Extremely important to reshape and refine the datasets into usable datasets, which can further used for analytics.

# %% [markdown]
# **Visualization** is an essential method in any data scientist’s toolbox.
# - After data wrangling visualization is a key first step in the exploration of most data sets.
# - Exploring data visually and with simple summary statistics is known as **Exploratory Data Analysis (EDA)**.
# - Never build analytical or machine learning models until examined data and understand the relationships.
# - Otherwise, risk of wasting time in building models blindly.
# - Visualization is also a powerful tool for presentation of results.
#
# **Static visualizations** can offer only a single “view” of data.
# - Multiple static views needed to present variety of perspectives on the same information.
# - Number of dimensions of data are limited.
# - Representing multidimensional datasets fairly in static images is difficult.
#
# - Visualizing data on Web quickest way to reach global audience.
# - Big need of making dynamic, interactive web applications for sharing of plots.

# %% [markdown]
# **Python** programming language has strong appeal for data wrangling and visualization.
# - Released in 1991 is interpreted programming language.
# - Python is general purpose, easy to use in analytical and quantitative computing.
# - Open source and flexible.
# - Massive libraries for manipulation of data
# - Libraries are extremely easy to learn and use.
# - For those who are familiar with programming languages such as, Java, c++ etc.
# - Python has large and active scientific computing and data analysis community.

# %% [markdown]
# # Pandas
# - Developed by Wes McKinney in 2008.
# - Big need of flexible, high performance tool.
# - Pandas is open source library for data wrangling.
# - Prior to pandas Python was used for data wrangling.
# - Writing programs from scratch was painfull for data wrangling.
# - Pandas load, prepare, manipulate, visualization and analyse.<br><br>
# ## Key features<br>
# - Fast and efficient DataFrame object with default and customized indexing.
# - Load data from different file formats.
# - Data alignment and integrated handling of missing data.
# - Reshaping and pivoting of data sets.
# - Label-based slicing, indexing and sub setting of large data sets.
# - Columns from a data structure can be deleted or inserted.
# - Group by data for aggregation and transformations.
# - High performance merging and joining of data.
# - Time Series functionality.

# %% [markdown]
# ## 1. pandas data structure
# - Pandas has two data structures, **Series** and **DataFrame**.

# %% [markdown]
#  ### 1.1 Series:
# - One dimensional array like data structure but with additional labelling called as index.
# - To make a series pass a list of elements as an argument to Series() data structure.

# %%
import pandas as pd
series=pd.Series([10,20,30,40])
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ### 1.2 dataFrame
# - Rectangular table of data with ordered collection of columns.
# - Each column can accept different value type (numeric, string, Boolean etc.).
#
# #### Defining a dataFrame
# - Pass dictionary of equal lengths of keys as an argument to pandas dataFrame() class.

# %% [markdown]
# A column from a dataframe can be retrieved by either dict-like notation or by attribute.

# %%
students=pd.DataFrame({'id':[1,2,3,4,5],
                  'name':['Mohit','Rohit','Sohit','Abhishek','Ankit'],
                  'roll_num':[20961,20961,20963,20964,20965]})
students
# Out:
#    id      name  roll_num
# 0   1     Mohit     20961
# 1   2     Rohit     20961
# 2   3     Sohit     20963
# 3   4  Abhishek     20964
# 4   5     Ankit     20965

# %%
students['name']
# Out:
# 0       Mohit
# 1       Rohit
# 2       Sohit
# 3    Abhishek
# 4       Ankit
# Name: name, dtype: object

# %% [markdown]
# ## 2. Parsing data using pandas
# - Pandas has functions via which it can accept data externally.
# - Data is stored as an object of DataFrame.
# - The table below shows the pandas functions used for parsing data in DataFrame.

# %%
from IPython.display import Image
Image("C:/Users/Mohit Kumar/Desktop/seminar/parsing Fn.png")

# %% [markdown]
#  ### 2.1 Read html data
#    - read_html() function is used to read data from a table on a web-page
#    - pass web page address as an arguments.

# %%
import pandas as pd
html_table=pd.read_html('https://www.theguardian.com/football/premierleague/table',header=0)
html_table[0].head()
# Out:
#    P       Team  GP   W  D  L   F   A  GD  Pts  \
# 0  1   Man City  27  21  2  4  74  20  54   65
# 1  2  Liverpool  26  20  5  1  59  15  44   65
# 2  3      Spurs  26  20  0  6  54  25  29   60
# 3  4    Man Utd  26  15  6  5  52  35  17   51
# 4  5    Arsenal  26  15  5  6  53  37  16   50
#
#                                                 Form
# 0  Won against Huddersfield Lost to Newcastle Won...
# 1  Won against Brighton Won against C Palace Drew...
# 2  Lost to Man Utd Won against Fulham Won against...
# 3  Won against Spurs Won against Brighton Drew wi...
# 4  Lost to West Ham Won against Chelsea Won again...

# %% [markdown]
# ### 2.2. Reading data from MySql table
#    - Data can be read from mysql table using pymysql and sqlalchemy packages
#    - sqlalchemy package make connection.
#    - Pandas read_sql_table() function read table.

# %%
import pandas as pd
import pymysql 
import sqlalchemy
engine=sqlalchemy.create_engine('mysql+pymysql://root:9896598724@localhost:3306/seminar')
sql_data=pd.read_sql_table('data',engine)
sql_data
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 8         15.04  1.96    Male     No  Sun  Dinner     2
# 9         14.78  3.23    Male     No  Sun  Dinner     2
# 10        10.27  1.71    Male     No  Sun  Dinner     2
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 12        15.42  1.57    Male     No  Sun  Dinner     2
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 14        14.83  3.02  Female     No  Sun  Dinner     2
# 15        21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %% [markdown]
# ### 2.3 Reading data from a csv file
# - pandas read_csv( ) function is used
# - pass path of file as an argument to this file

# %%
import pandas as pd
auto_prices=pd.read_csv('C:\\Users\\Mohit Kumar\\Documents\\Data\\auto_prices.csv')
auto_prices.head()
# Out:
#    symboling normalized-losses         make oil-type aspiration  \
# 0          3                 ?  alfa-romero      gas        std
# 1          3                 ?  alfa-romero      gas        std
# 2          1                 ?  alfa-romero      gas        std
# 3          2               164         audi      gas        std
# 4          2               164         audi      gas        std
#
#   num-of-windows   body-style drive-wheels engine-location  wheel-base  ...    \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## 3. Data cleaning using pandas
#  **Pandas has functions for data cleaning. These function makes life of data wrangler easier.**

# %% [markdown]
# ## 3.1 Renaming of columns
# - rename() function of DataFrame is used to rename columns as well as index axis.
# - Pass a dictionary to columns argument.
# - Assign to this dictionary as current name as key and new name as its value.

# %%
auto_prices.rename(columns={'oil-type':'fuel-type',
                           'num-of-windows':'num-of-doors'},inplace=True)
auto_prices.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# ## 3.2 Replacing a value
# - Value can be replaced to a new value.
# - By using replace() of DataFrame.
# - Pass old value and new value as first and second argument.

# %%
import numpy as np
auto_prices.replace('?',np.nan,inplace=True)
auto_prices
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2               NaN         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1               NaN         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0               NaN         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %% [markdown]
# ## 3.3 Handling missing data
# - Pandas uses the floating-point value NaN to represent missing value.
# - Sentinel values for pandas DataFrame.
# - It is easily detected by pandas.
# - Depending upon situations null values are treated in different ways.
# - They are either dropped.
# - Or filled by value.
# - Or filling with a forward or backward value.
# - To handle missing values pandas dataframe has following functions
#     1. dropna()
#     2. fillna()
#     3. isnull()
#     4. notnull()

# %% [markdown]
# ## 3.3.1 Checking missing values
# 1. Use isnull() function
# 2. Or use notnull() function

# %%
auto_prices.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# ### 3.3.2 Dropping null vaues
# - dropna() function is used.
# - Rows that has a NaN value are removed.

# %%
auto_prices.dropna(inplace=True)
auto_prices
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# 6            1               158        audi       gas        std
# 8            1               158        audi       gas      turbo
# 10           2               192         bmw       gas        std
# 11           0               192         bmw       gas        std
# 12           0               188         bmw       gas        std
# 13           0               188         bmw       gas        std
# 18           2               121   chevrolet       gas        std
# 19           1                98   chevrolet       gas        std
# 20           0                81   chevrolet       gas        std
# 21           1               118       dodge       gas        std
# 22           1               118       dodge       gas        std
# ...

# %% [markdown]
# ## 4. Combining data sets
# - Required when data is dispersed in more than one datasets
# - Then need to merge those datasets.
# - It is easily possible using pandas.
# - Pandas concat() function can used.
# - Pass as an arguments a series of data-sets that to be merged.
# - By default it merge data-sets along axis=0 i.e. along rows.
# - If required datasets can be merged along columns
# - By passing as an argument axis=1.

# %%
sql_data1=sql_data.iloc[0:120]
sql_data1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
sql_data2=sql_data[120:]
sql_data2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 120       11.69  2.31    Male     No  Thur   Lunch     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 123       15.95  2.00    Male     No  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 127       14.52  2.00  Female     No  Thur   Lunch     2
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 129       22.82  2.18    Male     No  Thur   Lunch     3
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 131       20.27  2.83  Female     No  Thur   Lunch     2
# 132       11.17  1.50  Female     No  Thur   Lunch     2
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 134       18.26  3.25  Female     No  Thur   Lunch     2
# ...

# %%
merge=pd.concat([sql_data1,sql_data2])
merge
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 8         15.04  1.96    Male     No  Sun  Dinner     2
# 9         14.78  3.23    Male     No  Sun  Dinner     2
# 10        10.27  1.71    Male     No  Sun  Dinner     2
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 12        15.42  1.57    Male     No  Sun  Dinner     2
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 14        14.83  3.02  Female     No  Sun  Dinner     2
# 15        21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
sql_data.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sql_data3=sql_data.reindex(columns=['total_bill', 'tip', 'sex', 'smoker'])
sql_data3
# Out:
#      total_bill   tip     sex smoker
# 0         16.99  1.01  Female     No
# 1         10.34  1.66    Male     No
# 2         21.01  3.50    Male     No
# 3         23.68  3.31    Male     No
# 4         24.59  3.61  Female     No
# 5         25.29  4.71    Male     No
# 6          8.77  2.00    Male     No
# 7         26.88  3.12    Male     No
# 8         15.04  1.96    Male     No
# 9         14.78  3.23    Male     No
# 10        10.27  1.71    Male     No
# 11        35.26  5.00  Female     No
# 12        15.42  1.57    Male     No
# 13        18.43  3.00    Male     No
# 14        14.83  3.02  Female     No
# 15        21.58  3.92    Male     No
# 16        10.33  1.67  Female     No
# 17        16.29  3.71    Male     No
# 18        16.97  3.50  Female     No
# 19        20.65  3.35    Male     No
# 20        17.92  4.08    Male     No
# 21        20.29  2.75  Female     No
# 22        15.77  2.23  Female     No
# 23        39.42  7.58    Male     No
# ...

# %%
sql_data4=sql_data.reindex(columns=['day', 'time', 'size'])
sql_data4
# Out:
#      day    time  size
# 0    Sun  Dinner     2
# 1    Sun  Dinner     3
# 2    Sun  Dinner     3
# 3    Sun  Dinner     2
# 4    Sun  Dinner     4
# 5    Sun  Dinner     4
# 6    Sun  Dinner     2
# 7    Sun  Dinner     4
# 8    Sun  Dinner     2
# 9    Sun  Dinner     2
# 10   Sun  Dinner     2
# 11   Sun  Dinner     4
# 12   Sun  Dinner     2
# 13   Sun  Dinner     4
# 14   Sun  Dinner     2
# 15   Sun  Dinner     2
# 16   Sun  Dinner     3
# 17   Sun  Dinner     3
# 18   Sun  Dinner     3
# 19   Sat  Dinner     3
# 20   Sat  Dinner     2
# 21   Sat  Dinner     2
# 22   Sat  Dinner     2
# 23   Sat  Dinner     4
# 24   Sat  Dinner     2
# 25   Sat  Dinner     4
# 26   Sat  Dinner     2
# 27   Sat  Dinner     2
# 28   Sat  Dinner     2
# 29   Sat  Dinner     2
# ..   ...     ...   ...
# 213  Sat  Dinner     2
# 214  Sat  Dinner     3
# 215  Sat  Dinner     2
# 216  Sat  Dinner     5
# 217  Sat  Dinner     2
# 218  Sat  Dinner     2
# 219  Sat  Dinner     4
# 220  Fri   Lunch     2
# ...

# %%
mergeA=pd.concat([sql_data3,sql_data4],axis=1)
mergeA
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 8         15.04  1.96    Male     No  Sun  Dinner     2
# 9         14.78  3.23    Male     No  Sun  Dinner     2
# 10        10.27  1.71    Male     No  Sun  Dinner     2
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 12        15.42  1.57    Male     No  Sun  Dinner     2
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 14        14.83  3.02  Female     No  Sun  Dinner     2
# 15        21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %% [markdown]
# ## 5. Pivot table
# - Pivot table is a data summarization tool.
# - It aggregates a table of data by one or more keys.
# - Arrange the data in a rectangle.
# - Some of the group keys along the rows and some along the columns.
# - DataFrame has a pivot_table() function.
# - There is also a top-level pandas.pivot_table() function.
# - pivot_table() can add partial totals also known as margins.

# %%
pd.pivot_table(sql_data,index=['sex'],columns=['smoker'])
# Out:
#             size                 tip           total_bill
# smoker        No       Yes        No       Yes         No        Yes
# sex
# Female  2.603774  2.242424  2.769245  2.931515  18.092453  17.977879
# Male    2.711340  2.500000  3.113402  3.051167  19.791237  22.284500

# %% [markdown]
# ## 6. Cross-Tabulations
# - Special case of a pivot table that computes group frequencies.
# - Pandas crosstab() function is used for cross-tabulation.
# - It accept two compulsory arguments index and columns
# - Assign the data variables to these arguments.

# %%
pd.crosstab(index=sql_data['sex'],columns=sql_data['smoker'])
# Out:
# smoker  No  Yes
# sex
# Female  53   33
# Male    97   60

# %% [markdown]
# # Matplotlib
#
# - Matplotlib is a python library for making 2D plots.
# - It makes heavy use of NumPy and other extension code to provide good performance even for large arrays.
# - matplotlib.pyplot is a collection functions that make matplotlib work like MATLAB.
# - Each pyplot function makes some change to a figure
#     - Creates a figure.
#     - Creates a plotting area in a figure.
#     - Plots some lines in a plotting area.
#     - Decorates the plot with labels, etc.
#
#
# - Here is the list of functions of matplotlib.pyplot.
# - These functions are used to plot histograms, bar graphs, line plot, scatter plot, and many more plots.

# %%
from IPython.display import Image
Image("C:/Users/Mohit Kumar/Desktop/seminar/MatplotlibFn.png")

# %% [markdown]
# As an example hist() function is used to plot histogram

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(sql_data['total_bill'],bins=20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 27., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # Seaborn
# - Python library for visualization of data.
# - Provide eye candy statistical plots.
# - And at the same time it makes developer's life easier.
# - Or in other words, it is a high level API to visualize data.
# -  Built on top of Matplotlib.
# - Seaborn has strong integration with pandas data structures.
# - It is developed for plotting with pandas data structures and it belongs to pandas eco-system.
#
# **Seaborn has following type of plotting functions:**
#
# ## 1. Visualizing statistical relationships
# - Variables in a dataset are said to be related if one variable changes, then the other variables also changes.
# - Scatter plot and line plots are used to check whether variables are related.
# - Seaborn’s relplot() function  used to plot scatter and line plot.
#
# ### 1.1 Scatter plot
# - It depicts the relationship between two variables.
# - Plot points, where each point is an observation in the dataset.
# - There are various ways to plot a scatteplot.
# - But most common approach is to use relplot() function and setting kind=’scatter’
# - Additional dimensions can be view by assigning categorical variables to row, col, hue parameters.

# %%
import matplotlib
# %matplotlib inline
import seaborn as sns
data=pd.DataFrame({'time':np.arange(500),
                   'value':np.random.randn(500).cumsum()   
})

sns.relplot(data=data,x='time',y='value')

# %% [markdown]
# ### 1.2 Line plot
# - If one of the variable is function of time, better to use line plot.
# - Set kind=’line’ in relplot() function.

# %%
sns.relplot(data=data,x='time',y='value',kind='line')

# %% [markdown]
# ## 2. Plotting with categorical data
# - If one of the main variables is categorical.
# - catplot() function of seaborn is used to plot.
# - Several plots can be plot using catplot() function.
# - This function accept x, y, and data as arguments.
# - x for x axis variable,y for y axis variable.
# - data for dataframe on which plot is to drawn,
# - These argumesnts are compulsory to pass.
# - Possible to view Additional dimensions.
# - But they also be categorical.
# - Set categorical variable to hue, row, col arguments.
# - Another important argument is kind, to plot different kind of categorical plots.
#
# ### 2.1 Categorical scatter plot
# - Default plot of catplot()  function scatterplot.
# - All the points belonging to same category fall on the same position of the axis corresponding to the categorical axes.
# - There are two categorical scatter plots in seaborn.
#   1. #### Striplot:
#         - It adjust position of points on categorical axes with small amount of random jitter.
#         - jitter parameter controls the magnitude of jitter or disable it. To disable jitter, pass jiiter argument as false.

# %%
import matplotlib
# %matplotlib inline
sns.catplot(data=auto_prices,x='body-style',y='wheel-base',kind='strip')

# %% [markdown]
# #### 2. Swarmplot:
# - It adjust the position of points on categorical axes.
# - That prevents them from overlapping.
# - It is drawn by setting kind=’’swarm’’ in catplot() function.

# %%
sns.catplot(data=auto_prices,x='body-style',y='wheel-base',kind='swarm')

# %% [markdown]
# ### 3. Categorical distribution plots
# - As the size of datasets grows, categorical scatter plots become limited in the information they can provide.
# - Several alternative approaches for summarization of categorical variables.

# %% [markdown]
#  #### 3.1 Boxplots
#  - Shows three quartile values in the box,
#  - Whiskers extends to the points that lie in the **1.5*IQR** (inter quartile range)
#  - Extreme observations shown independently.
#  - Boxplot is plotted by setting kind=’box’ in catplot() function.

# %%
sns.catplot(data=auto_prices,x='body-style',y='engine-size',kind='box')

# %% [markdown]
# #### 3.2. Boxenplot
#
# - Related function to box plot is boxenplot(),
# - It shows more information about distribution.
# - It is more suitable for large dataset.
# - Set kind='boxen' in catplot() function.

# %%
sns.catplot(data=auto_prices,x='body-style',y='engine-size',kind='boxen')

# %% [markdown]
# #### 3.3 Violinplots
#
# - Based on hybrid approach that combine boxplot with kernel density estimation procedure.
# - So it represent more information on same plot.
# - Set kind=’violin’ in catplot() method of seaborn.
# - Thick bar in centre represents the inter-quartile range
# - Thin black line extended from it represents the 95% confidence intervals.
# - White dot is the median.

# %%
sns.catplot(data=auto_prices,x='body-style',y='engine-size',kind='violin')

# %% [markdown]
# ### 4. Categorical estimation plots-
# - Used to show estimate of central tendency.
# - Bar plot,count-plot and point plots are used.
#
#      #### 4.1 Bar plots
#      - Barplot() function can also be used.
#      - It operate on a full data set.
#      - Estimate central tendency for a particular category and plot it.
#      - To plot barplot set kind=”bar” in catplot() function.

# %%
sns.catplot(data=auto_prices,x='body-style',kind='bar',y='engine-size')

# %% [markdown]
#  #### 4.2 Countplot
#
#    - Special case of barplot()
#    - It shows number of observation in each category.
#    - To plot this, pass kind='count' in catplot() function.

# %%
sns.catplot(data=auto_prices,x='body-style',kind='count')

# %% [markdown]
#  #### 4.3 Point plots
#
#    - Alternative to bar plot,it visualize same information.
#    - But instead of plotting bar, it plots the point estimate and confidence interval.
#    - To plot this set kind='point' in catplot().

# %%
sns.catplot(data=auto_prices,x='body-style',kind='point',y='engine-size')

# %% [markdown]
# ## 5. Visualizing the distribution of a dataset
# - When dealing with data, it is an important task to know about how the variables are distributed.
# - i.e. plot univariate and bivariate distribution of variables.
#
#
# ### 5.1 Plotting univariate distribution
#    - The simplest way to plot a univariate distribution in seaborn by distplot().
#    - By default it draw a histogram and kernel density estimation (KDE) on same plot.
#    - Pass the variable as an argument to distplot() function.
#    - Another important argument is **bins**, by default it is 10.

# %%
sns.distplot(auto_prices['engine-size'])

# %% [markdown]
# #### 5.1.1 Histogram
#
# - Diagram consisting of bins, along the range of variable.
# - Area of bins are proportional to the number of observation in each bin.
# - To plot a histogram remove KDE curve in distplot() by setting kde=False.

# %%
sns.distplot(auto_prices['engine-size'],kde=False)

# %% [markdown]
# #### 5.1.2 Kernel density estimation(KDE)
# - KDE is used to plot the shape of distribution.
# - It has observation on one axis and their density on other axis.
# - KDE is plot by setting hist=False in distplot() function of seaborn or using kdeplot() function directly.

# %%
sns.distplot(auto_prices['engine-size'],hist=False)

# %% [markdown]
# ### 5.2 Plotting bivariate distributions
# - jointplot() function is used to visualize bivariate distribution.
# - It creates a multi-panel figure
# - That shows both the bivariate as well as univariate (or marginal) distributions on separate axes.

# %% [markdown]
# #### 5.2.1 Scatter plots
#
# - Scatter plot most common way to visualize a bivariate distribution.
# - Each data point is shown as a dot of x and y values.
# - jointplot() function by default plot scatter plot.
# - If some dots are over-plotted on each other
# - It is difficult to know actually how many dots are plotted.
# - That create difficulty in visualization.

# %%
auto_prices['price']=pd.to_numeric(auto_prices['price'])
sns.jointplot(auto_prices['price'],auto_prices['engine-size'])

# %% [markdown]
# #### 5.2.2 Hexbin plots
#
# - Hexbin plots are basically bivariate histograms.
# - As it shows the number of observations that fall within hexagonal bins.
# - Suitable for large datasets, where over-plotting of points occurs.
# - As a general rule scatter plots are used when data is small
# - in case of large datasets, use hexbin plot.
# - Set kind=”hex” in jointplot() function or by hexbin() function directly.

# %%
sns.jointplot(auto_prices['price'],auto_prices['engine-size'],kind='hexbin')

# %% [markdown]
# #### 5.2.3 Kernel density estimation
# - It is also possible to use kernel density estimation to visualize a bivariate distribution.
# - this kind of plot is shown with a contour plot.
# - Set kind parameter to “kde” in distplot() function, or use kdeplot() function directly

# %%
sns.jointplot(data=auto_prices,x='engine-size',y='price')

# %% [markdown]
# ## 6. Visualizing pairwise relationships in a dataset
# - Multiple variables are to be plot on the same plot.
# - Already multiple variables are plotted in same figure.
# - But they were categorical variables.
# - For quantitative variables, pairplot() function is used.
# - This creates a matrix of axes and shows the relationship of each pair of columns
# - By default off diagonal axes are plotting a scatter plot and diagonal axes plot hist.
# - Diagonal plot can be changed to kde by setting diag_kind parameter to kde.

# %%
sns.pairplot(data=auto_prices,vars=['city-mpg','highway-mpg', 'price'])

# %% [markdown]
# ## 7. Linear regression models:
#
# - Linear relationship between two variables is determined through linear regression.
# - Seaborn has two functions, regplot() and lmplot(), to visualize linear relationships.
# - They both are closely related.
# - Both draw a scatterplot of two variables, x and y.
# - Then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.
# - Pass both variables in this function as an x and y arguments.
# - By default confidence interval width is 95%.
# - But it can be changed by assigning integer value in [0,100] to argument “ci”.

# %%
sns.regplot(data=auto_prices,x='engine-size',y='price')

# %% [markdown]
# ### Plotting regression line using lmplot():
# - Pass the x and y variables In lmplot()
# - lmplot() function accepts hue, row, and col.
# - So lmplot() function can be extended to multi-dimensions.

# %%
sns.lmplot(data=auto_prices,x='engine-size',y='price')

# %% [markdown]
# ## 8. Heatmap
# - Heatmap uses a system of color-coding to represent different values.
# - A simple heat map provides an immediate visual summary of data.
# - More elaborate heat maps allows viewers to understand complex data sets.
# - Before plotting heat map, cross-tabulated or pivoted data is required.
# - In seaborn, heatmap() function is used to plot a heat map.
# - An important parameter of heatmap() function is “annot”.
# - By default it is false, but when it is set to “True”, it will place the values in respective cells.

# %%
import matplotlib.pyplot as plt
fig,axes=plt.subplots(figsize=(10,10))
auto_cross=pd.crosstab(columns=[auto_prices['body-style'],auto_prices['fuel-type']],
                      index=[auto_prices['num-of-cylinders'],auto_prices['drive-wheels']])
sns.heatmap(data=auto_cross,annot=True)

# %% [markdown]
# # Dash
# - Plotly formally released Dash In June of 2017
# - Open source library for creating interactive web-based visualizations.
# - Dash provides pure Python abstraction around HTML, CSS, and JavaScript.
# - Built on top of well-established open source frameworks like
#     - flask for serving the pages
#     - react.js for the javascript user interface
#     - plotly for making interactive graphs.
# - Build highly interactive web applications, solely using python code.
# - All the power and convenience of pandas and other python tools for manipulating the data is available.

# %% [markdown]
# ## 1. Dash layout
# - Dash applications are composed of two parts.
#     - First part describe the “layout” i.e. UI of the application
#     - Second part describe interactivity of the application.
# - Dash provides Python classes for all of the visual components of the application.
# - These components contained in
#     - dash_core_components
#     - dash_html_components
# - But it is also possible to compose own with JavaScript and React.js.

# %% [markdown]
# ### 1.1 Dash_core_components library
# - It contains a core set of components written by dash team.
# - It contains all the components that are used to built user interface, to make application interactive.
# - The components and their functions are described below:

# %%
from IPython.display import Image
Image("C:/Users/Mohit Kumar/Desktop/seminar/DashCoreComponents.png")

# %% [markdown]
# ### 1.2 Dash HTML Components
# - Dash provides pure Python abstraction around HTML, CSS.
# - This is possible due to dash html components.
# - So there is no need of using HTML or an HTML templating engine.

# %% [markdown]
# ## 2 Dash interactivity
# - Dash interactivity is possible due to the dash call-back decorators.
# - These decorators sensitive to the change in properties of components.

# %%
from IPython.display import Image
Image('C:\\Users\\Mohit Kumar\\Desktop\\plots\\slider.png')

# %% [markdown]
# In this example,”value” property of the Slider is the input to the app and the output of the app is the “figure” property of the Graph. <br><br>
# Whenever the value of the Slider changes, Dash calls the callback function update_figure with the new value. <br><br>The function filters the dataframe with this new value, constructs a figure object, and returns it to the Dash application.
# There are a few nice patterns in this example:
# 1.	Pandas library for importing and filtering datasets in memory.
# 2.	Dataframe df is loaded at the start of the app. This dataframe df is in the global state of the app and can be read inside the callback functions.
# 3.	The callback does not modify the original data, it just creates copies of the dataframe by filtered through pandas filters.

# %% [markdown]
# ## 3. Dash deployment
# - By default dash apps runs on local host.
# - But it is possible to share the dash apps on servers.
# - Dash apps can be deployed on a company’s server, or on AWS, Google Cloud, Azure or Heroku.
# - Here is an example of deploying dash app using **Heroku.**
# - This example require a Heroku account, git, virtualenv.

# %% [markdown]
# **Step1:** Make a new folder and initialize with git and virtualenv.<br>
# **Step2:**
#  - Initialize the folder with a sample app (app.py),
#  - .gitignore file, requirements.txt, and a Procfile for deployment of app.
#  - The contents of these files are shown in table below.

# %%
from IPython.display import Image
Image("C:/Users/Mohit Kumar/Desktop/seminar/filesContent.png")

# %% [markdown]
# #### Step3:
# Initialize Heroku, add files to Git, and deploy by following steps below in cmd:
# 1.	heroku create my-dash-app
# 2.	git add .
# 3.	git commit –m
# 4.	git push heroku master
# 5.	heroku ps:scale web=1
# <br>
# After these 3 steps a link to the app will be provided, share that link to share dash app.

# %% [markdown]
# # Summary
# - Python programming language has strong appeal towards data science as
#     - Open source.
#     - So many libraries for data wrangling and visualization.
# - For data wrangling pandas is used
#     - It has strong data structure to represent tabular data.
#     - Function to parse data from different sources.
#     - Data cleaning, handling missing values, merging data sets etc.
# - To visualize data low level matplotlib can be used.
# - But it is a base package for other high level packages such as seaborn.
#     - That draw well customized plot in just one line of code.
#     - Seaborn’s default customization satisfy almost all the times.
#     - But if required customization to plots can be done using matplotlib.
# - Last and important step is to make interactive web application for plotting.
# - Python has dash framework used to make interactive web application.
#     - Using python code and no need of javascript and html is required.
#     - These dash application can be published on any server as well as on clouds like google cloud but freely on heroku cloud.

# %% [markdown]
# # References<br>
# Barry, Paul(2011). Head First Python, first edition, O’Reilly Media, Inc., 1005 Gravenstein Highway North, Sebastopol, CA 95472.<br><br>
# dash.2018. Dash user guide (online). Available at https://dash.plot.ly/<br><br>
# heroku.2007. Heroku documentation (online). Available at https://devcenter.heroku.com/<br><br>
# Matplotlib.2018. Matplolib version 3.0.2 documentation (online). Available at https://matplotlib.org/contents.html<br><br>
# Lutz, Mark(2013). Learning Python, fifth edition, O’Reilly Media, Inc., 1005 Gravenstein Highway North, Sebastopol, CA 95472<br><br>
# pandas.2018. Pandas version: 0.24.1 documentation (online). Available at https://pandas.pydata.org/pandasdocs/stable/#<br><br>
# seaborn.2018. Seaborn version 0.9.0 documentation (online). Available at https://seaborn.pydata.org/<br><br>
